# %% [markdown]
# # 리뷰완료

# %% [markdown]
# 링크 : https://wikidocs.net/152922

# %% [markdown]
# # 한국어 BERT

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\146058\anaconda3\lib\site-packages (4.42.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: filelock in c:\users\146058\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in c:\users\146058\anaconda3\lib\site-packages (from transformers) (2.24.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (2020.10.15)
# Requirement already satisfied: packaging>=20.0 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (20.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (4.50.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in c:\users\146058\anaconda3\lib\site-packages (from transformers) (1.23.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\146058\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\146058\anaconda3\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\146058\anaconda3\lib\site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\146058\anaconda3\lib\site-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\146058\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: six in c:\users\146058\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (1.15.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\146058\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\146058\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (3.7.4.3)

# %%
import transformers
transformers.__version__
# Out:
# '4.42.3'

# %%
from transformers import TFBertForMaskedLM

# %%
model = TFBertForMaskedLM.from_pretrained('klue/bert-base', from_pt=True)
# Out:
# HBox(children=(HTML(value='pytorch_model.bin'), FloatProgress(value=0.0, max=445025130.0), HTML(value='')))

# %%
# !pip install tensorflow==2.13.0

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("klue/bert-base")

# %%
inputs = tokenizer('축구는 정말 재미있는 [MASK]다.', return_tensors='tf')

# %%
tokenizer.cls_token_id

# %%
tokenizer.sep_token_id

# %%
tokenizer.mask_token_id

# %%
print(inputs['input_ids'])

# %%
print(inputs['token_type_ids'])

# %%
print(inputs['attention_mask'])

# %%
from transformers import FillMaskPipeline
pip = FillMaskPipeline(model=model, tokenizer=tokenizer)

# %%
pip('축구는 정말 재미있는 [MASK]다.')

# %%
pip('어벤져스는 정말 재미있는 [MASK]다.')

# %%
pip('나는 오늘 아침에 [MASK]에 출근을 했다.')
